# %% [markdown]
# ASIAN PAINT STOCK ANALYSIS(2002-2020)

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as py

# %%
of=pd.read_csv('asian.csv')

# %%
of.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  2002-07-01  21.367001  22.466999  21.367001  22.287001   1.582765   87810
# 1  2002-07-02  21.370001  22.783001  21.370001  22.520000   1.599312  588615
# 2  2002-07-03  22.267000  22.799999  21.933001  22.733000   1.614439  162075
# 3  2002-07-04  22.667000  23.333000  22.667000  22.966999   1.631057  266625
# 4  2002-07-05  23.400000  25.000000  23.333000  24.056999   1.708466  408600

# %%
of.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  4420.000000  4420.000000  4420.000000  4420.000000  4420.000000
# mean    493.326608   499.205410   487.080099   493.073845   455.495347
# std     507.806946   513.361461   501.722135   507.551998   518.573205
# min      20.132999    21.007000    20.132999    20.773001     1.582765
# 25%      70.199997    71.500000    69.087500    70.172503    27.065418
# 50%     283.002502   286.595001   279.317505   282.555008   209.366203
# 75%     864.124985   874.675018   852.887482   862.137482   836.129929
# max    1889.000000  1916.699951  1878.199951  1893.699951  1886.122192
#
#              Volume
# count  4.420000e+03
# mean   7.557108e+05
# std    8.492052e+05
# min    0.000000e+00
# 25%    1.827825e+05
# 50%    5.544915e+05
# 75%    1.029685e+06
# max    1.871721e+07

# %%
dates=of['Date']

# %%
dates
# Out:
# 0       2002-07-01
# 1       2002-07-02
# 2       2002-07-03
# 3       2002-07-04
# 4       2002-07-05
#            ...
# 4415    2020-06-01
# 4416    2020-06-02
# 4417    2020-06-03
# 4418    2020-06-04
# 4419    2020-06-05
# Name: Date, Length: 4420, dtype: object

# %%
vol=[]
yr=['2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020']
for date in yr:
    v=[of['Volume'].loc[of['Date'].str.contains(date)]]
    vol.append(v)

# %%
vol
# Out:
# [[0       87810
#   1      588615
#   2      162075
#   3      266625
#   4      408600
#           ...
#   120    147645
#   121     83250
#   122      9375
#   123     26310
#   124     82995
#   Name: Volume, Length: 125, dtype: int64], [125     12885
#   126     15960
#   127     21945
#   128     25155
#   129     33825
#           ...
#   371    182310
#   372    241890
#   373    589810
#   374    194050
#   375    985760
#   Name: Volume, Length: 251, dtype: int64], [376    476740
#   377    334800
#   378    773080
#   379    542030
#   380    371970
#           ...
#   623     67930
#   624    178620
#   625    300090
#   626    125600
#   627    205120
#   Name: Volume, Length: 252, dtype: int64], [628    172730
#   629    322400
#   630    305000
#   631    389850
#   632    176210
#           ...
#   871     96060
#   872    242170
#   873    191320
#   874    154440
#   875    222400
#   Name: Volume, Length: 248, dtype: int64], [876     134740
#   877     157310
# ...

# %%
vol[0][0].sum()
# Out:
# 20087220

# %%
vol[0]
# Out:
# [0       87810
#  1      588615
#  2      162075
#  3      266625
#  4      408600
#          ...
#  120    147645
#  121     83250
#  122      9375
#  123     26310
#  124     82995
#  Name: Volume, Length: 125, dtype: int64]

# %%
df=pd.DataFrame()

# %%
df['Year']=yr

# %%
df
# Out:
#     Year
# 0   2002
# 1   2003
# 2   2004
# 3   2005
# 4   2006
# 5   2007
# 6   2008
# 7   2009
# 8   2010
# 9   2011
# 10  2012
# 11  2013
# 12  2014
# 13  2015
# 14  2016
# 15  2017
# 16  2018
# 17  2019
# 18  2020

# %%
vol[1]
# Out:
# [125     12885
#  126     15960
#  127     21945
#  128     25155
#  129     33825
#          ...
#  371    182310
#  372    241890
#  373    589810
#  374    194050
#  375    985760
#  Name: Volume, Length: 251, dtype: int64]

# %%
len(vol)
# Out:
# 19

# %%
yr_vol=[]
for v in vol:
    s=v[0].sum()
    yr_vol.append(s)

# %%
yr_vol
# Out:
# [20087220,
#  60742795,
#  79056640,
#  87642610,
#  75982130,
#  99214280,
#  84788760,
#  83724050,
#  180877120,
#  215311990,
#  205212560,
#  246614475,
#  262969888,
#  322388837,
#  278004893,
#  208358228,
#  266998574,
#  322105841,
#  240160928]

# %%
df['Volume']=yr_vol

# %%
df
# Out:
#     Year     Volume
# 0   2002   20087220
# 1   2003   60742795
# 2   2004   79056640
# 3   2005   87642610
# 4   2006   75982130
# 5   2007   99214280
# 6   2008   84788760
# 7   2009   83724050
# 8   2010  180877120
# 9   2011  215311990
# 10  2012  205212560
# 11  2013  246614475
# 12  2014  262969888
# 13  2015  322388837
# 14  2016  278004893
# 15  2017  208358228
# 16  2018  266998574
# 17  2019  322105841
# 18  2020  240160928

# %%
max(yr_vol)
# Out:
# 322388837

# %%
yr_vol.index(max(yr_vol))
# Out:
# 13

# %%
plt.bar(df['Year'],df['Volume'])
plt.xticks(rotation=90)
plt.xlabel('Years')
plt.ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

# %%
yr_vol.index(min(yr_vol))
# Out:
# 0

# %% [markdown]
# #From this it can be concluded that the stock had the highest volume during the year 2015 and the lowest volume during the year 2002

# %%
of
# Out:
#             Date         Open         High          Low        Close  \
# 0     2002-07-01    21.367001    22.466999    21.367001    22.287001
# 1     2002-07-02    21.370001    22.783001    21.370001    22.520000
# 2     2002-07-03    22.267000    22.799999    21.933001    22.733000
# 3     2002-07-04    22.667000    23.333000    22.667000    22.966999
# 4     2002-07-05    23.400000    25.000000    23.333000    24.056999
# ...          ...          ...          ...          ...          ...
# 4415  2020-06-01  1706.500000  1711.900024  1681.500000  1693.250000
# 4416  2020-06-02  1693.250000  1733.000000  1680.000000  1709.300049
# 4417  2020-06-03  1724.000000  1744.000000  1705.849976  1716.550049
# 4418  2020-06-04  1716.449951  1719.599976  1627.000000  1633.750000
# 4419  2020-06-05  1650.000000  1659.349976  1621.000000  1638.550049
#
#         Adj Close   Volume
# 0        1.582765    87810
# 1        1.599312   588615
# 2        1.614439   162075
# ...

# %%
high=list(of['High'])

# %%
high
# Out:
# [22.466999053955078,
#  22.783000946044922,
#  22.79999923706055,
#  23.33300018310547,
#  25.0,
#  24.867000579833984,
#  24.63999938964844,
#  24.60000038146973,
#  24.267000198364254,
#  24.33300018310547,
#  24.132999420166016,
#  23.65999984741211,
#  22.982999801635746,
#  23.33300018310547,
#  22.66699981689453,
#  22.533000946044922,
#  22.65999984741211,
#  22.933000564575195,
#  23.60000038146973,
#  23.433000564575195,
#  23.60000038146973,
#  22.66699981689453,
#  22.79999923706055,
#  22.382999420166016,
#  21.993000030517575,
#  22.1200008392334,
#  22.299999237060547,
#  22.459999084472656,
#  22.533000946044922,
#  22.533000946044922,
#  22.663000106811523,
#  22.60000038146973,
#  25.267000198364254,
#  22.57999992370605,
#  22.533000946044922,
#  22.933000564575195,
#  23.0,
#  22.66699981689453,
#  22.6200008392334,
#  22.79999923706055,
#  22.933000564575195,
#  23.09000015258789,
#  22.867000579833984,
#  22.792999267578125,
#  23.0,
#  23.0,
# ...

# %%
maxh=high.index(max(high))

# %%
maxh
# Out:
# 4345

# %%
of.loc[maxh]
# Out:
# Date         2020-02-12
# Open               1880
# High             1916.7
# Low              1878.2
# Close            1893.7
# Adj Close       1886.12
# Volume          1616826
# Name: 4345, dtype: object

# %% [markdown]
# #The highest value acquired by the stock in between the years 2002 to 2020 is 1916.7 on 2020-02-12.

# %%
of
# Out:
#             Date         Open         High          Low        Close  \
# 0     2002-07-01    21.367001    22.466999    21.367001    22.287001
# 1     2002-07-02    21.370001    22.783001    21.370001    22.520000
# 2     2002-07-03    22.267000    22.799999    21.933001    22.733000
# 3     2002-07-04    22.667000    23.333000    22.667000    22.966999
# 4     2002-07-05    23.400000    25.000000    23.333000    24.056999
# ...          ...          ...          ...          ...          ...
# 4415  2020-06-01  1706.500000  1711.900024  1681.500000  1693.250000
# 4416  2020-06-02  1693.250000  1733.000000  1680.000000  1709.300049
# 4417  2020-06-03  1724.000000  1744.000000  1705.849976  1716.550049
# 4418  2020-06-04  1716.449951  1719.599976  1627.000000  1633.750000
# 4419  2020-06-05  1650.000000  1659.349976  1621.000000  1638.550049
#
#         Adj Close   Volume
# 0        1.582765    87810
# 1        1.599312   588615
# 2        1.614439   162075
# ...

# %%
v=list(of['Volume'])

# %%
of.loc[v.index(max(v))]
# Out:
# Date         2011-05-31
# Open              309.2
# High              338.7
# Low                 305
# Close            313.34
# Adj Close       221.254
# Volume         18717210
# Name: 2205, dtype: object

# %% [markdown]
# #The highest volume acquired by this stock was 18717210 on 2011-05-31.

# %% [markdown]
# #Performance of the stock over the years

# %%
plt.plot(of['Date'],of['High'])

# %% [markdown]
# #RELATION GRAPHS

# %%
import seaborn as sns
# %matplotlib inline

# %%
 of
# Out:
#             Date         Open         High          Low        Close  \
# 0     2002-07-01    21.367001    22.466999    21.367001    22.287001
# 1     2002-07-02    21.370001    22.783001    21.370001    22.520000
# 2     2002-07-03    22.267000    22.799999    21.933001    22.733000
# 3     2002-07-04    22.667000    23.333000    22.667000    22.966999
# 4     2002-07-05    23.400000    25.000000    23.333000    24.056999
# ...          ...          ...          ...          ...          ...
# 4415  2020-06-01  1706.500000  1711.900024  1681.500000  1693.250000
# 4416  2020-06-02  1693.250000  1733.000000  1680.000000  1709.300049
# 4417  2020-06-03  1724.000000  1744.000000  1705.849976  1716.550049
# 4418  2020-06-04  1716.449951  1719.599976  1627.000000  1633.750000
# 4419  2020-06-05  1650.000000  1659.349976  1621.000000  1638.550049
#
#         Adj Close   Volume
# 0        1.582765    87810
# 1        1.599312   588615
# 2        1.614439   162075
# ...

# %%
sns.distplot(of['High'])

# %%
sns.distplot(of['Volume'])

# %%
sns.pairplot(of)

# %%
sns.jointplot(x='Volume',y='Open',data=of)

# %%
sns.barplot(x='Date',y='High',data=of)

# %%
corr=of.corr()

# %%
sns.heatmap(corr)

# %% [markdown]
# #Predicting stock values using LSTM model

# %%
of.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  2002-07-01  21.367001  22.466999  21.367001  22.287001   1.582765   87810
# 1  2002-07-02  21.370001  22.783001  21.370001  22.520000   1.599312  588615
# 2  2002-07-03  22.267000  22.799999  21.933001  22.733000   1.614439  162075
# 3  2002-07-04  22.667000  23.333000  22.667000  22.966999   1.631057  266625
# 4  2002-07-05  23.400000  25.000000  23.333000  24.056999   1.708466  408600

# %%
asianpaint=of

# %%
training_set=asianpaint.iloc[:,1:2].values

# %%
training_set
# Out:
# array([[  21.36700058],
#        [  21.37000084],
#        [  22.2670002 ],
#        ...,
#        [1724.        ],
#        [1716.44995117],
#        [1650.        ]])

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler(feature_range=(0,1))
training_set_scaled=sc.fit_transform(training_set)

# %%
training_set_scaled
# Out:
# array([[6.60293728e-04],
#        [6.61899118e-04],
#        [1.14186872e-03],
#        ...,
#        [9.11711213e-01],
#        [9.07671306e-01],
#        [8.72115030e-01]])

# %%
x_train=[]
y_train=[]
for i in range(60,1258):
    x_train.append(training_set_scaled[i-60:i,0])
    y_train.append(training_set_scaled[i,0])
x_train,y_train=np.array(x_train),np.array(y_train)
x_train=np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
# Out:
# Using TensorFlow backend.

# %%
reg=Sequential()

# %%
reg.add(LSTM(units=50,return_sequences=True,input_shape=(x_train.shape[1],1)))
reg.add(Dropout(0.2))

# %%
reg.add(LSTM(units=50,return_sequences=True))
reg.add(Dropout(0.2))

# %%
reg.add(LSTM(units=50,return_sequences=True))
reg.add(Dropout(0.2))

# %%
reg.add(LSTM(units=50))
reg.add(Dropout(0.2))

# %%
reg.add(Dense(units=1))

# %%
reg.compile(optimizer='adam',loss='mean_squared_error',metrics=['accuracy'])

# %%
reg.fit(x_train,y_train,epochs=100,batch_size=32)
# Out:
# Epoch 1/100
# 1198/1198 [==============================] - 12s 10ms/step - loss: 9.3132e-05 - accuracy: 0.0000e+00
# Epoch 2/100
# 1198/1198 [==============================] - 8s 7ms/step - loss: 1.2814e-05 - accuracy: 0.0000e+00
# Epoch 3/100
# 1198/1198 [==============================] - 9s 7ms/step - loss: 5.3498e-06 - accuracy: 0.0000e+00
# Epoch 4/100
# 1198/1198 [==============================] - 9s 7ms/step - loss: 6.0868e-06 - accuracy: 0.0000e+00
# Epoch 5/100
# 1198/1198 [==============================] - 9s 8ms/step - loss: 6.0063e-06 - accuracy: 0.0000e+00
# Epoch 6/100
# 1198/1198 [==============================] - 9s 7ms/step - loss: 5.7891e-06 - accuracy: 0.0000e+00
# Epoch 7/100
# 1198/1198 [==============================] - 9s 8ms/step - loss: 5.7913e-06 - accuracy: 0.0000e+00
# Epoch 8/100
# 1198/1198 [==============================] - 9s 8ms/step - loss: 5.1671e-06 - accuracy: 0.0000e+00
# Epoch 9/100
# ...

# %%
dataset_test=pd.read_csv('asian.csv')

# %%
real_stock_price=dataset_test.iloc[:,1:2].values

# %%
dataset_total=pd.concat((asianpaint['Open'],asianpaint['Open']),axis=0)
inputs=dataset_total[len(dataset_total)-len(dataset_test)-60:].values
inputs=inputs.reshape(-1,1)
inputs=sc.transform(inputs)
x_test=[]
for i in range(60,80):
    x_test.append(inputs[i-60:i,0])
x_test=np.array(x_test)
x_test=np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))
predicted_stock_price=reg.predict(x_test)
predixted_stock_price=sc.inverse_transform(predicted_stock_price)

# %%
plt.plot(real_stock_price,color='red',label='Real Price')
plt.plot(predicted_stock_price,color='blue',label='Predicted Price')
plt.legend()
plt.show()
